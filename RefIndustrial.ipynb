# %% [markdown]
#   ### Análise de Dados - Refrigeração Industrial

# %% [markdown]
# ###### Tratamento dos dados

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 16.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 32.3 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=db1f3e44c7eef1850b603a5b1507056ea480b26dbfec3c10d4c171a90642e282
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...

# %%
import pandas as pd
import matplotlib.dates as dt
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/drive/MyDrive/2023.2/BaseDados_RefIndustrial_RV0.csv", sep =";", decimal=",")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1356 entries, 0 to 1355
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Medição                          1356 non-null   object
#  1   Data                             1351 non-null   object
#  2   Hora                             1351 non-null   object
#  3   Fator de Potência                1351 non-null   float64
#  4   Potência Ativa                   1351 non-null   float64
#  5   Energia Ativa                    1351 non-null   float64
#  6   Temperatura ambiente             1351 non-null   float64
#  7   Temperatura de superaquecimento  1350 non-null   float64
#  8   Abertura de Válvula              1344 non-null   float64
#  9   Setpoint                         1349 non-null   float64
# dtypes: float64(7), object(3)
# memory usage: 106.1+ KB

# %%
data['Data'] = pd.to_datetime(data['Data'])
data['Hora'] = pd.to_datetime(data['Hora'], format='%H:%M')

# %%
data['Hora'] = pd.to_datetime(data['Hora'], format='%H:%M')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1356 entries, 0 to 1355
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Medição                          1356 non-null   object
#  1   Data                             1351 non-null   object
#  2   Hora                             1351 non-null   object
#  3   Fator de Potência                1351 non-null   float64
#  4   Potência Ativa                   1351 non-null   float64
#  5   Energia Ativa                    1351 non-null   float64
#  6   Temperatura ambiente             1351 non-null   float64
#  7   Temperatura de superaquecimento  1351 non-null   object
#  8   Abertura de Válvula              1344 non-null   float64
#  9   Setpoint                         1349 non-null   float64
# dtypes: float64(6), object(4)
# memory usage: 106.1+ KB

# %%
data['Temperatura de superaquecimento'] = data['Temperatura de superaquecimento'].str.replace('ERRO','')

data['Temperatura de superaquecimento'] = pd.to_numeric(data['Temperatura de superaquecimento'].str.replace(',','.'))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1356 entries, 0 to 1355
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Medição                          1356 non-null   object
#  1   Data                             1351 non-null   object
#  2   Hora                             1351 non-null   object
#  3   Fator de Potência                1351 non-null   float64
#  4   Potência Ativa                   1351 non-null   float64
#  5   Energia Ativa                    1351 non-null   float64
#  6   Temperatura ambiente             1351 non-null   float64
#  7   Temperatura de superaquecimento  1350 non-null   float64
#  8   Abertura de Válvula              1344 non-null   float64
#  9   Setpoint                         1349 non-null   float64
# dtypes: float64(7), object(3)
# memory usage: 106.1+ KB

# %%
data.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#   Medição        Data      Hora  Fator de Potência  Potência Ativa  \
# 0      1ª         NaN       NaN                NaN             NaN
# 1      1ª  09/11/2023  17:02:02                1.0             0.0
# 2      1ª  09/11/2023  17:02:32                1.0             0.0
# 3      1ª  09/11/2023  17:03:02                1.0             0.0
# 4      1ª  09/11/2023  17:03:30                1.0             0.0
#
#    Energia Ativa  Temperatura ambiente  Temperatura de superaquecimento  \
# 0            NaN                   NaN                              NaN
# 1            0.0                   0.0                             26.3
# ...

# %%
data1 = data.dropna(how="any")
data1.tail()
# Out:
#      Medição        Data      Hora  Fator de Potência  Potência Ativa  \
# 1344      5ª  17/11/2023  18:15:00                0.8          2415.0
# 1345      5ª  17/11/2023  18:15:30                0.8          2494.0
# 1346      5ª  17/11/2023  18:16:00                0.8          2392.0
# 1347      5ª  17/11/2023  18:16:30                0.8          2395.0
# 1348      5ª  17/11/2023  18:17:00                0.8          2390.0
#
#       Energia Ativa  Temperatura ambiente  Temperatura de superaquecimento  \
# 1344          996.0                   4.0                             11.8
# 1345         1016.0                   3.3                              8.8
# 1346         1036.0                   2.2                             12.1
# 1347         1056.0                   1.3                             11.4
# 1348         1076.0                   0.2                             11.2
#
#       Abertura de Válvula  Setpoint
# 1344                  0.8       0.8
# ...

# %%
data2 = data[(data["Abertura de Válvula"] > 0)]

# %%
data2
# Out:
#      Medição        Data      Hora  Fator de Potência  Potência Ativa  \
# 13        1ª  09/11/2023  17:08:02                0.8          1742.0
# 14        1ª  09/11/2023  17:08:31                0.8          1516.0
# 15        1ª  09/11/2023  17:09:01                0.8          1516.0
# 16        1ª  09/11/2023  17:09:31                0.8          2237.0
# 17        1ª  09/11/2023  17:10:01                0.8          2225.0
# ...      ...         ...       ...                ...             ...
# 1344      5ª  17/11/2023  18:15:00                0.8          2415.0
# 1345      5ª  17/11/2023  18:15:30                0.8          2494.0
# 1346      5ª  17/11/2023  18:16:00                0.8          2392.0
# 1347      5ª  17/11/2023  18:16:30                0.8          2395.0
# 1348      5ª  17/11/2023  18:17:00                0.8          2390.0
#
#       Energia Ativa  Temperatura ambiente  Temperatura de superaquecimento  \
# ...

# %% [markdown]
# ###### Análise dos dados

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(data2, title="Variação de Abertura da Válvula de Expanção")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-02-17 01:37:26.629538&quot;&gt;&lt;title&gt;Variação de Abertura da Válvula de Expanção&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
profile.to_file(output_file="/content/Refrigeracao_report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
